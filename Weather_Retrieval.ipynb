# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

coordinates = list(lat_lngs)

# %%
cities = []


# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city
len(cities)
# Out:
# 733

# %%
import requests
import time
from datetime import datetime
from config import API_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + API_key

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | oparino
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | fairbanks
# Processing Record 4 of Set 1 | la primavera
# Processing Record 5 of Set 1 | lebu
# Processing Record 6 of Set 1 | thompson
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | tuktoyaktuk
# Processing Record 9 of Set 1 | zhangye
# Processing Record 10 of Set 1 | summerside
# Processing Record 11 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 1 | mwaro
# Processing Record 13 of Set 1 | anloga
# Processing Record 14 of Set 1 | poum
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | pacific grove
# Processing Record 18 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 1 | bambous virieux
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | broken hill
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | hilo
# Processing Record 24 of Set 1 | barrow
# Processing Record 25 of Set 1 | sao felix do xingu
# Processing Record 26 of Set 1 | nogliki
# Processing Record 27 of Set 1 | castro
# Processing Record 28 of Set 1 | pundaguitan
# Processing Record 29 of Set 1 | khatanga
# Processing Record 30 of Set 1 | evensk
# Processing Record 31 of Set 1 | lao cai
# Processing Record 32 of Set 1 | pevek
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | cerritos
# Processing Record 35 of Set 1 | norman wells
# Processing Record 36 of Set 1 | vaini
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | atambua
# Processing Record 39 of Set 1 | mar del plata
# Processing Record 40 of Set 1 | svetlyy
# Processing Record 41 of Set 1 | clyde river
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | chokurdakh
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | aksum
# Processing Record 46 of Set 1 | port alfred
# Processing Record 47 of Set 1 | hithadhoo
# Processing Record 48 of Set 1 | tecoanapa
# Processing Record 49 of Set 1 | tsumeb
# Processing Record 50 of Set 1 | butaritari
# Processing Record 1 of Set 2 | bredasdorp
# Processing Record 2 of Set 2 | kuna
# Processing Record 3 of Set 2 | zambezi
# Processing Record 4 of Set 2 | olga
# Processing Record 5 of Set 2 | antalaha
# Processing Record 6 of Set 2 | tiksi
# Processing Record 7 of Set 2 | souillac
# Processing Record 8 of Set 2 | cherskiy
# Processing Record 9 of Set 2 | hobyo
# Processing Record 10 of Set 2 | ust-kuyga
# Processing Record 11 of Set 2 | lufilufi
# Processing Record 12 of Set 2 | shagonar
# Processing Record 13 of Set 2 | paamiut
# Processing Record 14 of Set 2 | hailar
# Processing Record 15 of Set 2 | odlabari
# Processing Record 16 of Set 2 | san patricio
# Processing Record 17 of Set 2 | maykain
# City not found. Skipping...
# Processing Record 18 of Set 2 | new norfolk
# Processing Record 19 of Set 2 | san joaquin
# Processing Record 20 of Set 2 | tasiilaq
# Processing Record 21 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 2 | puerto ayora
# Processing Record 23 of Set 2 | saldanha
# Processing Record 24 of Set 2 | carnarvon
# Processing Record 25 of Set 2 | saint anthony
# Processing Record 26 of Set 2 | berlevag
# Processing Record 27 of Set 2 | san isidro
# Processing Record 28 of Set 2 | kapaa
# Processing Record 29 of Set 2 | ponta do sol
# Processing Record 30 of Set 2 | hamilton
# Processing Record 31 of Set 2 | oranjemund
# Processing Record 32 of Set 2 | port blair
# Processing Record 33 of Set 2 | leningradskiy
# Processing Record 34 of Set 2 | avarua
# Processing Record 35 of Set 2 | qaanaaq
# Processing Record 36 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 2 | hermanus
# Processing Record 38 of Set 2 | dikson
# Processing Record 39 of Set 2 | narsaq
# Processing Record 40 of Set 2 | kralendijk
# Processing Record 41 of Set 2 | port hedland
# Processing Record 42 of Set 2 | nikolskoye
# Processing Record 43 of Set 2 | byron bay
# Processing Record 44 of Set 2 | emba
# Processing Record 45 of Set 2 | bolitoc
# Processing Record 46 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 2 | port elizabeth
# Processing Record 48 of Set 2 | hami
# Processing Record 49 of Set 2 | port moresby
# Processing Record 50 of Set 2 | kastamonu
# Processing Record 1 of Set 3 | acapulco
# Processing Record 2 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 3 | rioja
# Processing Record 4 of Set 3 | jamestown
# Processing Record 5 of Set 3 | mahebourg
# Processing Record 6 of Set 3 | muroto
# Processing Record 7 of Set 3 | jalu
# Processing Record 8 of Set 3 | elhovo
# Processing Record 9 of Set 3 | urumqi
# Processing Record 10 of Set 3 | asau
# Processing Record 11 of Set 3 | pont-sainte-maxence
# Processing Record 12 of Set 3 | siniscola
# Processing Record 13 of Set 3 | moranbah
# Processing Record 14 of Set 3 | brae
# Processing Record 15 of Set 3 | aljezur
# Processing Record 16 of Set 3 | baykit
# Processing Record 17 of Set 3 | gohpur
# Processing Record 18 of Set 3 | saint-augustin
# Processing Record 19 of Set 3 | constitucion
# Processing Record 20 of Set 3 | grand gaube
# Processing Record 21 of Set 3 | geraldton
# Processing Record 22 of Set 3 | saint-georges
# Processing Record 23 of Set 3 | longyearbyen
# Processing Record 24 of Set 3 | uetendorf
# Processing Record 25 of Set 3 | saint-joseph
# Processing Record 26 of Set 3 | tuatapere
# Processing Record 27 of Set 3 | palmerston
# Processing Record 28 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 3 | harrismith
# Processing Record 30 of Set 3 | grinnell
# Processing Record 31 of Set 3 | babushkin
# Processing Record 32 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 3 | trat
# Processing Record 34 of Set 3 | stoyba
# City not found. Skipping...
# Processing Record 35 of Set 3 | fort saint john
# City not found. Skipping...
# Processing Record 36 of Set 3 | faanui
# Processing Record 37 of Set 3 | ilulissat
# Processing Record 38 of Set 3 | alugan
# Processing Record 39 of Set 3 | opuwo
# Processing Record 40 of Set 3 | tsiroanomandidy
# Processing Record 41 of Set 3 | arraial do cabo
# Processing Record 42 of Set 3 | saint-philippe
# Processing Record 43 of Set 3 | kidal
# Processing Record 44 of Set 3 | codrington
# Processing Record 45 of Set 3 | aksu
# Processing Record 46 of Set 3 | sabha
# Processing Record 47 of Set 3 | dhidhdhoo
# Processing Record 48 of Set 3 | flinders
# Processing Record 49 of Set 3 | ribeira grande
# Processing Record 50 of Set 3 | emerald
# Processing Record 1 of Set 4 | aksarka
# Processing Record 2 of Set 4 | georgetown
# Processing Record 3 of Set 4 | port lincoln
# Processing Record 4 of Set 4 | atuona
# Processing Record 5 of Set 4 | saskylakh
# Processing Record 6 of Set 4 | baculin
# Processing Record 7 of Set 4 | marsh harbour
# Processing Record 8 of Set 4 | navsi
# City not found. Skipping...
# Processing Record 9 of Set 4 | moree
# Processing Record 10 of Set 4 | vardo
# Processing Record 11 of Set 4 | isangel
# Processing Record 12 of Set 4 | fort nelson
# Processing Record 13 of Set 4 | listvyanskiy
# Processing Record 14 of Set 4 | tessalit
# Processing Record 15 of Set 4 | lagoa
# Processing Record 16 of Set 4 | kavaratti
# Processing Record 17 of Set 4 | newport
# Processing Record 18 of Set 4 | vezirkopru
# Processing Record 19 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 20 of Set 4 | enshi
# Processing Record 21 of Set 4 | ocos
# Processing Record 22 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 4 | gambiran
# Processing Record 24 of Set 4 | guerrero negro
# Processing Record 25 of Set 4 | namatanai
# Processing Record 26 of Set 4 | lavrentiya
# Processing Record 27 of Set 4 | okhotsk
# Processing Record 28 of Set 4 | victoria
# Processing Record 29 of Set 4 | coahuayana
# Processing Record 30 of Set 4 | olafsvik
# Processing Record 31 of Set 4 | dakar
# Processing Record 32 of Set 4 | iguape
# Processing Record 33 of Set 4 | ostrovnoy
# Processing Record 34 of Set 4 | rudnya
# Processing Record 35 of Set 4 | la crosse
# Processing Record 36 of Set 4 | rio grande
# Processing Record 37 of Set 4 | chicama
# Processing Record 38 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 4 | kabinda
# Processing Record 41 of Set 4 | bengkulu
# Processing Record 42 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 4 | lively
# Processing Record 44 of Set 4 | cairo
# Processing Record 45 of Set 4 | bembereke
# Processing Record 46 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 4 | ossora
# Processing Record 48 of Set 4 | kampot
# Processing Record 49 of Set 4 | provideniya
# Processing Record 50 of Set 4 | aklavik
# Processing Record 1 of Set 5 | kaitangata
# Processing Record 2 of Set 5 | agadir
# Processing Record 3 of Set 5 | killin
# Processing Record 4 of Set 5 | aquiraz
# Processing Record 5 of Set 5 | ola
# Processing Record 6 of Set 5 | kodiak
# Processing Record 7 of Set 5 | ketchikan
# Processing Record 8 of Set 5 | verkhnevilyuysk
# Processing Record 9 of Set 5 | murmashi
# Processing Record 10 of Set 5 | verkh-suetka
# Processing Record 11 of Set 5 | edgewater
# Processing Record 12 of Set 5 | miranorte
# City not found. Skipping...
# Processing Record 13 of Set 5 | laguna
# Processing Record 14 of Set 5 | mangalam
# Processing Record 15 of Set 5 | gao
# Processing Record 16 of Set 5 | salalah
# Processing Record 17 of Set 5 | batagay-alyta
# Processing Record 18 of Set 5 | takoradi
# Processing Record 19 of Set 5 | pontianak
# Processing Record 20 of Set 5 | belmonte
# Processing Record 21 of Set 5 | rawson
# Processing Record 22 of Set 5 | vaitape
# Processing Record 23 of Set 5 | syrskoye
# Processing Record 24 of Set 5 | college
# Processing Record 25 of Set 5 | zhigansk
# Processing Record 26 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 5 | nalut
# Processing Record 28 of Set 5 | jiuquan
# Processing Record 29 of Set 5 | sorland
# Processing Record 30 of Set 5 | port hueneme
# Processing Record 31 of Set 5 | voloshka
# Processing Record 32 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 33 of Set 5 | kawalu
# Processing Record 34 of Set 5 | sitka
# Processing Record 35 of Set 5 | waingapu
# Processing Record 36 of Set 5 | vavuniya
# Processing Record 37 of Set 5 | sorong
# Processing Record 38 of Set 5 | bethel
# Processing Record 39 of Set 5 | sibolga
# Processing Record 40 of Set 5 | qaqortoq
# Processing Record 41 of Set 5 | griffith
# Processing Record 42 of Set 5 | erzin
# Processing Record 43 of Set 5 | pocone
# Processing Record 44 of Set 5 | basco
# Processing Record 45 of Set 5 | japura
# Processing Record 46 of Set 5 | klaksvik
# Processing Record 47 of Set 5 | merauke
# Processing Record 48 of Set 5 | los llanos de aridane
# Processing Record 49 of Set 5 | nouadhibou
# Processing Record 50 of Set 5 | upernavik
# Processing Record 1 of Set 6 | nyakabindi
# Processing Record 2 of Set 6 | east london
# Processing Record 3 of Set 6 | havelock
# Processing Record 4 of Set 6 | melo
# Processing Record 5 of Set 6 | borama
# City not found. Skipping...
# Processing Record 6 of Set 6 | srednekolymsk
# Processing Record 7 of Set 6 | camalu
# Processing Record 8 of Set 6 | moengo
# Processing Record 9 of Set 6 | jose bonifacio
# Processing Record 10 of Set 6 | gat
# Processing Record 11 of Set 6 | yantal
# Processing Record 12 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 6 | calama
# Processing Record 14 of Set 6 | paraiso
# Processing Record 15 of Set 6 | areia branca
# Processing Record 16 of Set 6 | ukiah
# Processing Record 17 of Set 6 | plouzane
# Processing Record 18 of Set 6 | rorvik
# Processing Record 19 of Set 6 | hervey bay
# Processing Record 20 of Set 6 | pisco
# Processing Record 21 of Set 6 | hirara
# Processing Record 22 of Set 6 | solnechnyy
# Processing Record 23 of Set 6 | talnakh
# Processing Record 24 of Set 6 | galle
# Processing Record 25 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 26 of Set 6 | pringsewu
# Processing Record 27 of Set 6 | altamira
# Processing Record 28 of Set 6 | hambantota
# Processing Record 29 of Set 6 | ordynskoye
# Processing Record 30 of Set 6 | jitra
# Processing Record 31 of Set 6 | abu jubayhah
# City not found. Skipping...
# Processing Record 32 of Set 6 | niltepec
# Processing Record 33 of Set 6 | liaozhong
# Processing Record 34 of Set 6 | ati
# Processing Record 35 of Set 6 | kattivakkam
# Processing Record 36 of Set 6 | yenagoa
# Processing Record 37 of Set 6 | katobu
# Processing Record 38 of Set 6 | airai
# Processing Record 39 of Set 6 | syracuse
# Processing Record 40 of Set 6 | sao joao da barra
# Processing Record 41 of Set 6 | skibbereen
# Processing Record 42 of Set 6 | impfondo
# Processing Record 43 of Set 6 | haines junction
# Processing Record 44 of Set 6 | krasnoselkup
# Processing Record 45 of Set 6 | abu samrah
# Processing Record 46 of Set 6 | huarmey
# Processing Record 47 of Set 6 | honiara
# Processing Record 48 of Set 6 | el sauzal
# Processing Record 49 of Set 6 | killam
# Processing Record 50 of Set 6 | kavieng
# Processing Record 1 of Set 7 | vestmanna
# Processing Record 2 of Set 7 | ialibu
# Processing Record 3 of Set 7 | seydi
# Processing Record 4 of Set 7 | marawi
# Processing Record 5 of Set 7 | zaozerne
# Processing Record 6 of Set 7 | the pas
# Processing Record 7 of Set 7 | basse-pointe
# Processing Record 8 of Set 7 | sioux lookout
# Processing Record 9 of Set 7 | maralal
# Processing Record 10 of Set 7 | sotnikovskoye
# Processing Record 11 of Set 7 | angoche
# Processing Record 12 of Set 7 | tsogni
# Processing Record 13 of Set 7 | cayenne
# Processing Record 14 of Set 7 | cincu
# Processing Record 15 of Set 7 | craigieburn
# Processing Record 16 of Set 7 | nanortalik
# Processing Record 17 of Set 7 | muyezerskiy
# Processing Record 18 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 7 | the valley
# Processing Record 20 of Set 7 | dujuma
# City not found. Skipping...
# Processing Record 21 of Set 7 | yar-sale
# Processing Record 22 of Set 7 | iqaluit
# Processing Record 23 of Set 7 | nerchinskiy zavod
# Processing Record 24 of Set 7 | hasaki
# Processing Record 25 of Set 7 | chililabombwe
# Processing Record 26 of Set 7 | portland
# Processing Record 27 of Set 7 | morgan hill
# Processing Record 28 of Set 7 | dwarka
# Processing Record 29 of Set 7 | severo-kurilsk
# Processing Record 30 of Set 7 | atar
# Processing Record 31 of Set 7 | inta
# Processing Record 32 of Set 7 | jian
# Processing Record 33 of Set 7 | zhoucheng
# Processing Record 34 of Set 7 | rawlins
# Processing Record 35 of Set 7 | pec
# Processing Record 36 of Set 7 | helong
# Processing Record 37 of Set 7 | karema
# Processing Record 38 of Set 7 | uruzgan
# Processing Record 39 of Set 7 | alihe
# Processing Record 40 of Set 7 | bardiyah
# Processing Record 41 of Set 7 | sao filipe
# Processing Record 42 of Set 7 | te anau
# Processing Record 43 of Set 7 | mercedes
# Processing Record 44 of Set 7 | grand junction
# Processing Record 45 of Set 7 | alyangula
# Processing Record 46 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 47 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 7 | meulaboh
# Processing Record 49 of Set 7 | rocha
# Processing Record 50 of Set 7 | tres picos
# Processing Record 1 of Set 8 | ust-nera
# Processing Record 2 of Set 8 | blizhne-pesochnoye
# Processing Record 3 of Set 8 | mandalgovi
# Processing Record 4 of Set 8 | kankon
# Processing Record 5 of Set 8 | polaniec
# Processing Record 6 of Set 8 | leshukonskoye
# Processing Record 7 of Set 8 | lompoc
# Processing Record 8 of Set 8 | shatsk
# Processing Record 9 of Set 8 | adrar
# Processing Record 10 of Set 8 | esperance
# Processing Record 11 of Set 8 | laiyang
# Processing Record 12 of Set 8 | san ramon de la nueva oran
# Processing Record 13 of Set 8 | okato
# Processing Record 14 of Set 8 | coquimbo
# Processing Record 15 of Set 8 | tautira
# Processing Record 16 of Set 8 | sinnamary
# Processing Record 17 of Set 8 | camana
# Processing Record 18 of Set 8 | wellington
# Processing Record 19 of Set 8 | fukue
# Processing Record 20 of Set 8 | broome
# Processing Record 21 of Set 8 | laredo
# Processing Record 22 of Set 8 | bereda
# Processing Record 23 of Set 8 | mazagao
# Processing Record 24 of Set 8 | balvi
# Processing Record 25 of Set 8 | sarakhs
# Processing Record 26 of Set 8 | san andres
# Processing Record 27 of Set 8 | launceston
# Processing Record 28 of Set 8 | biltine
# Processing Record 29 of Set 8 | tawnat
# City not found. Skipping...
# Processing Record 30 of Set 8 | la ronge
# Processing Record 31 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 32 of Set 8 | sangar
# Processing Record 33 of Set 8 | luderitz
# Processing Record 34 of Set 8 | channel-port aux basques
# Processing Record 35 of Set 8 | manta
# Processing Record 36 of Set 8 | marzuq
# Processing Record 37 of Set 8 | san cristobal
# Processing Record 38 of Set 8 | askiz
# Processing Record 39 of Set 8 | faya
# Processing Record 40 of Set 8 | camamu
# Processing Record 41 of Set 8 | porbandar
# Processing Record 42 of Set 8 | saint george
# Processing Record 43 of Set 8 | alakurtti
# Processing Record 44 of Set 8 | bulanash
# Processing Record 45 of Set 8 | nome
# Processing Record 46 of Set 8 | aban
# Processing Record 47 of Set 8 | mao
# Processing Record 48 of Set 8 | kruisfontein
# Processing Record 49 of Set 8 | makakilo city
# Processing Record 50 of Set 8 | sobolevo
# Processing Record 1 of Set 9 | chuy
# Processing Record 2 of Set 9 | kijini
# Processing Record 3 of Set 9 | alofi
# Processing Record 4 of Set 9 | kirovsk
# Processing Record 5 of Set 9 | lorengau
# Processing Record 6 of Set 9 | akom
# Processing Record 7 of Set 9 | trail
# Processing Record 8 of Set 9 | caceres
# Processing Record 9 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 10 of Set 9 | khani
# Processing Record 11 of Set 9 | micheweni
# Processing Record 12 of Set 9 | abu zabad
# Processing Record 13 of Set 9 | carutapera
# Processing Record 14 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 15 of Set 9 | wajir
# Processing Record 16 of Set 9 | wagar
# Processing Record 17 of Set 9 | kathu
# Processing Record 18 of Set 9 | dosso
# Processing Record 19 of Set 9 | berbera
# Processing Record 20 of Set 9 | kahului
# Processing Record 21 of Set 9 | del rio
# Processing Record 22 of Set 9 | sokolovyy
# Processing Record 23 of Set 9 | garissa
# Processing Record 24 of Set 9 | santiago del estero
# Processing Record 25 of Set 9 | manado
# Processing Record 26 of Set 9 | paita
# Processing Record 27 of Set 9 | husavik
# Processing Record 28 of Set 9 | amalapuram
# Processing Record 29 of Set 9 | quimperle
# Processing Record 30 of Set 9 | abha
# Processing Record 31 of Set 9 | duluth
# Processing Record 32 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 33 of Set 9 | litoral del san juan
# City not found. Skipping...
# Processing Record 34 of Set 9 | sevierville
# Processing Record 35 of Set 9 | tubuala
# Processing Record 36 of Set 9 | ahipara
# Processing Record 37 of Set 9 | kenai
# Processing Record 38 of Set 9 | kudahuvadhoo
# Processing Record 39 of Set 9 | laukaa
# Processing Record 40 of Set 9 | mount isa
# Processing Record 41 of Set 9 | havre-saint-pierre
# Processing Record 42 of Set 9 | lata
# Processing Record 43 of Set 9 | pangnirtung
# Processing Record 44 of Set 9 | comodoro rivadavia
# Processing Record 45 of Set 9 | kabansk
# Processing Record 46 of Set 9 | arman
# Processing Record 47 of Set 9 | camacha
# Processing Record 48 of Set 9 | itaituba
# Processing Record 49 of Set 9 | puri
# Processing Record 50 of Set 9 | ballitoville
# Processing Record 1 of Set 10 | inirida
# Processing Record 2 of Set 10 | san antonio
# Processing Record 3 of Set 10 | jagatsinghapur
# Processing Record 4 of Set 10 | bireun
# Processing Record 5 of Set 10 | prien
# Processing Record 6 of Set 10 | muhos
# Processing Record 7 of Set 10 | peruibe
# Processing Record 8 of Set 10 | tommot
# Processing Record 9 of Set 10 | churapcha
# Processing Record 10 of Set 10 | fray bentos
# Processing Record 11 of Set 10 | saint-francois
# Processing Record 12 of Set 10 | cabedelo
# Processing Record 13 of Set 10 | courtalam
# City not found. Skipping...
# Processing Record 14 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 15 of Set 10 | santa maria
# Processing Record 16 of Set 10 | antofagasta
# Processing Record 17 of Set 10 | sikourion
# City not found. Skipping...
# Processing Record 18 of Set 10 | itoman
# Processing Record 19 of Set 10 | kenora
# Processing Record 20 of Set 10 | redmond
# Processing Record 21 of Set 10 | blankenberge
# Processing Record 22 of Set 10 | mehamn
# Processing Record 23 of Set 10 | coos bay
# Processing Record 24 of Set 10 | tank
# Processing Record 25 of Set 10 | les cayes
# Processing Record 26 of Set 10 | uyemskiy
# Processing Record 27 of Set 10 | egvekinot
# Processing Record 28 of Set 10 | port huron
# Processing Record 29 of Set 10 | vence
# Processing Record 30 of Set 10 | vila franca do campo
# Processing Record 31 of Set 10 | itapirapua
# Processing Record 32 of Set 10 | chimoio
# Processing Record 33 of Set 10 | sterling
# Processing Record 34 of Set 10 | torbay
# Processing Record 35 of Set 10 | cidreira
# Processing Record 36 of Set 10 | chimore
# Processing Record 37 of Set 10 | turtas
# Processing Record 38 of Set 10 | bathsheba
# Processing Record 39 of Set 10 | tiruchchendur
# Processing Record 40 of Set 10 | padang
# Processing Record 41 of Set 10 | cabo san lucas
# Processing Record 42 of Set 10 | ambon
# Processing Record 43 of Set 10 | wa
# City not found. Skipping...
# Processing Record 44 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 45 of Set 10 | mayo
# Processing Record 46 of Set 10 | gejiu
# Processing Record 47 of Set 10 | beringovskiy
# Processing Record 48 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 10 | nelson bay
# Processing Record 50 of Set 10 | iskateley
# Processing Record 1 of Set 11 | tabou
# Processing Record 2 of Set 11 | upata
# Processing Record 3 of Set 11 | linxia
# Processing Record 4 of Set 11 | kasiri
# Processing Record 5 of Set 11 | vagay
# Processing Record 6 of Set 11 | half moon bay
# Processing Record 7 of Set 11 | limbang
# Processing Record 8 of Set 11 | fortuna
# Processing Record 9 of Set 11 | yuncheng
# Processing Record 10 of Set 11 | bekhtery
# Processing Record 11 of Set 11 | ankang
# Processing Record 12 of Set 11 | ferme-neuve
# Processing Record 13 of Set 11 | jizan
# Processing Record 14 of Set 11 | fayaoue
# Processing Record 15 of Set 11 | ust-omchug
# Processing Record 16 of Set 11 | christchurch
# Processing Record 17 of Set 11 | touros
# Processing Record 18 of Set 11 | parry sound
# Processing Record 19 of Set 11 | udachnyy
# Processing Record 20 of Set 11 | nemuro
# Processing Record 21 of Set 11 | agadez
# Processing Record 22 of Set 11 | quesnel
# Processing Record 23 of Set 11 | luena
# Processing Record 24 of Set 11 | conde
# Processing Record 25 of Set 11 | marathon
# Processing Record 26 of Set 11 | quatre cocos
# Processing Record 27 of Set 11 | talara
# Processing Record 28 of Set 11 | inongo
# Processing Record 29 of Set 11 | mandera
# Processing Record 30 of Set 11 | labrea
# Processing Record 31 of Set 11 | port-gentil
# Processing Record 32 of Set 11 | santa fe
# Processing Record 33 of Set 11 | manono
# Processing Record 34 of Set 11 | roma
# Processing Record 35 of Set 11 | potsdam
# Processing Record 36 of Set 11 | kibaya
# Processing Record 37 of Set 11 | baruun-urt
# Processing Record 38 of Set 11 | hunchun
# Processing Record 39 of Set 11 | pokhara
# Processing Record 40 of Set 11 | basoko
# Processing Record 41 of Set 11 | fonte boa
# Processing Record 42 of Set 11 | mogadishu
# Processing Record 43 of Set 11 | ugoofaaru
# Processing Record 44 of Set 11 | kapoeta
# Processing Record 45 of Set 11 | gamba
# Processing Record 46 of Set 11 | ballina
# Processing Record 47 of Set 11 | richards bay
# Processing Record 48 of Set 11 | bandarbeyla
# Processing Record 49 of Set 11 | trapani
# Processing Record 50 of Set 11 | metro
# Processing Record 1 of Set 12 | dubenskiy
# City not found. Skipping...
# Processing Record 2 of Set 12 | san ramon
# Processing Record 3 of Set 12 | saint-pierre
# Processing Record 4 of Set 12 | matara
# Processing Record 5 of Set 12 | avera
# Processing Record 6 of Set 12 | teknaf
# Processing Record 7 of Set 12 | turukhansk
# Processing Record 8 of Set 12 | san quintin
# Processing Record 9 of Set 12 | muswellbrook
# Processing Record 10 of Set 12 | vanimo
# Processing Record 11 of Set 12 | gangotri
# City not found. Skipping...
# Processing Record 12 of Set 12 | paragominas
# Processing Record 13 of Set 12 | curillo
# Processing Record 14 of Set 12 | ilorin
# Processing Record 15 of Set 12 | pyapon
# Processing Record 16 of Set 12 | mayskiy
# Processing Record 17 of Set 12 | cape elizabeth
# City not found. Skipping...
# Processing Record 18 of Set 12 | juifang
# City not found. Skipping...
# Processing Record 19 of Set 12 | calbuco
# Processing Record 20 of Set 12 | soyo
# Processing Record 21 of Set 12 | kungurtug
# Processing Record 22 of Set 12 | toora-khem
# Processing Record 23 of Set 12 | sisimiut
# Processing Record 24 of Set 12 | suntar
# Processing Record 25 of Set 12 | nushki
# Processing Record 26 of Set 12 | moose factory
# Processing Record 27 of Set 12 | conceicao do araguaia
# Processing Record 28 of Set 12 | jati
# Processing Record 29 of Set 12 | parabel
# Processing Record 30 of Set 12 | thai nguyen
# Processing Record 31 of Set 12 | kazerun
# Processing Record 32 of Set 12 | rosarito
# Processing Record 33 of Set 12 | maniitsoq
# Processing Record 34 of Set 12 | akureyri
# Processing Record 35 of Set 12 | zabid
# Processing Record 36 of Set 12 | labuhan
# Processing Record 37 of Set 12 | ust-tsilma
# Processing Record 38 of Set 12 | luebo
# Processing Record 39 of Set 12 | pochutla
# Processing Record 40 of Set 12 | arrifes
# Processing Record 41 of Set 12 | baiyin
# Processing Record 42 of Set 12 | dezful
# Processing Record 43 of Set 12 | santarem
# Processing Record 44 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 12 | kloulklubed
# Processing Record 46 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 47 of Set 12 | kapiri mposhi
# Processing Record 48 of Set 12 | depok
# Processing Record 49 of Set 12 | elizabeth city
# Processing Record 50 of Set 12 | santona

# %%
len(city_data)
city_data_df = pd.DataFrame(city_data)
city_data_df.head(20)
# Out:
#                City      Lat       Lng  Max Temp Current Description  \
# 0           Oparino  59.8518   48.2783     34.59       broken clouds
# 1           Rikitea -23.1203 -134.9692     74.82          light rain
# 2         Fairbanks  64.8378 -147.7164     67.48       broken clouds
# 3      La Primavera   5.4906  -70.4092     76.66       broken clouds
# 4              Lebu -37.6167  -73.6500     47.68    scattered clouds
# 5          Thompson  55.7435  -97.8558     60.96    scattered clouds
# 6            Hobart -42.8794  147.3294     50.25    scattered clouds
# 7       Tuktoyaktuk  69.4541 -133.0374     33.80       broken clouds
# 8           Zhangye  38.9342  100.4517     68.50     overcast clouds
# 9        Summerside  46.3959  -63.7876     59.13       broken clouds
# 10            Mwaro  -3.5000   29.6667     54.48     overcast clouds
# 11           Anloga   5.7947    0.8973     80.91    scattered clouds
# 12             Poum -20.2333  164.0167     77.22    scattered clouds
# 13        Cape Town -33.9258   18.4232     61.21     overcast clouds
# 14          Ushuaia -54.8000  -68.3000     40.66    scattered clouds
# 15    Pacific Grove  36.6177 -121.9166     75.31          few clouds
# 16  Bambous Virieux -20.3428   57.7575     70.05          few clouds
# 17      Yellowknife  62.4560 -114.3525     57.72          few clouds
# 18      Broken Hill -31.9500  141.4333     59.43     overcast clouds
# 19          Mataura -46.1927  168.8643     45.48    scattered clouds
#
#     Humidity  Cloudiness  Wind Speed Country
# 0         97          81        3.87      RU
# 1         75          17        1.70      PF
# 2         33          75       16.11      US
# 3         90          84        3.76      CO
# 4         82          37       16.51      CL
# 5         36          40       10.36      CA
# 6         93          40        8.05      AU
# 7         80          75        9.22      CA
# 8         31          88        2.48      CN
# 9         36          77       16.11      CA
# 10        88         100        2.15      BI
# 11        77          40        8.79      GH
# 12        71          41        6.49      NC
# 13        97         100        5.75      ZA
# 14        81          40       35.68      AR
# 15        81          20       14.00      US
# 16        88          20        3.44      MU
# 17        30          20        6.91      CA
# 18        74          91        4.00      AU
# 19        75          26        2.66      NZ

# %%
city_data_df.columns
new_column_order=["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", 
                    "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Oparino      RU  59.8518   48.2783     34.59        97          81
# 1       Rikitea      PF -23.1203 -134.9692     74.82        75          17
# 2     Fairbanks      US  64.8378 -147.7164     67.48        33          75
# 3  La Primavera      CO   5.4906  -70.4092     76.66        90          84
# 4          Lebu      CL -37.6167  -73.6500     47.68        82          37
# 5      Thompson      CA  55.7435  -97.8558     60.96        36          40
# 6        Hobart      AU -42.8794  147.3294     50.25        93          40
# 7   Tuktoyaktuk      CA  69.4541 -133.0374     33.80        80          75
# 8       Zhangye      CN  38.9342  100.4517     68.50        31          88
# 9    Summerside      CA  46.3959  -63.7876     59.13        36          77
#
#    Wind Speed Current Description
# 0        3.87       broken clouds
# 1        1.70          light rain
# 2       16.11       broken clouds
# 3        3.76       broken clouds
# 4       16.51    scattered clouds
# 5       10.36    scattered clouds
# 6        8.05    scattered clouds
# 7        9.22       broken clouds
# 8        2.48     overcast clouds
# 9       16.11       broken clouds

# %%
 city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
